# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
img_path = "E:\Project\OOC\LEDs_Data_Processing\LED_Decode\led_image\image_paper.png"
img = cv2.imread(img_path)
height, width, _ = img.shape
print(f'height:{height}, width:{width}')
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(img_gray, 0, 255, cv2.THRESH_BINARY +
    cv2.THRESH_OTSU)
# show thresholded image
plt.imshow(thresh, cmap='gray')
plt.show()
# Out:
# height:557, width:346

# %%
contours, hierarchy = cv2.findContours(
    thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE
)
boundingBox = []
for contour in contours:
    area = cv2.contourArea(contour)
    x, y, w, h = cv2.boundingRect(contour)
    boundingBox.append((x, y, w, h))
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 255), 2)

h_max = max(boundingBox[3])
if h_max != 0:
    print("h_max = ", h_max)
    print("y:", y)



plt.imshow(img, cmap='gray')
# Out:
# h_max =  334
# y: 329

# %%
def distance(focal_length, real_width, width_in_frame):
    return (focal_length * real_width) / width_in_frame
focal_length = 4.38/1000
real_width = 0.1
width_in_frame = h_max * 

dis = distance(focal_length, real_width, h_max)
print("distance = ", dis)
# Out:
# distance =  1.311377245508982e-06
