# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import font_manager, rcParams
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import plotly.offline as pyo
import plotly.graph_objects as go

# %%
path_file = "E:/Project/OOC/LEDs_Data_Processing/Encode_Decode/draw/data/yaw0_pitch20_roll0_edited.xlsx"
df = pd.read_excel(path_file)

# print(df1)

# %%
x_calculated = df.loc[:, 'x2']
y_calculated = df.loc[:, 'y2']
z_calculated = df.loc[:, 'z2']
x_samples = df.loc[:, 'X2']
y_samples = df.loc[:, 'Y2']
z_samples = df.loc[:, 'Z2']
# print(z_calculated)

delta_x = df.loc[:, 'delta_x2']
delta_y = df.loc[:, 'delta_y2']
delta_z = df.loc[:, 'delta_z2']

delta_xy = df.loc[:, 'delta_xy2']
delta_xyz = df.loc[:, 'delta_xyz2']

# %% [markdown]
# image for Conf

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman']
# plt.rcParams['font.weight'] = 'bold'
rcParams['font.family'] = 'Times New Roman'
# Define font properties for Times New Roman
legend_font = font_manager.FontProperties( style='normal', weight='normal', size=5)
label_font = {'style': 'normal', 'weight': 'normal', 'size': 30}
plt.figure(figsize=(20, 15))
ax = plt.gca()
ax.scatter(x_samples, y_samples, c='b', marker='o',s=70, label='Sample coordinates', alpha =1)
ax.scatter(x_calculated, y_calculated, c= 'r', marker='x',s=70, label='Calculated coordinates', alpha = 1)

ax.set_xlabel('X (cm)', fontdict={'weight': 'normal'}, fontsize=30)
ax.set_ylabel('Y (cm)', fontdict={'weight': 'normal'}, fontsize=30)
ax.legend(loc='upper center', fontsize=30,  bbox_to_anchor=(0.5, 1.09), ncol=2)

ax.set_xticks([-75, -50, -25, 0, 25, 50, 75])
ax.set_yticks([-75, -50, -25, 0, 25, 50, 75])

ax.set_xticklabels(['-75', '-50', '-25', '0', '25', '50', '75'], fontsize=30, weight='normal')  # Change to normal case
ax.set_yticklabels(['-75', '-50', '-25', '0', '25', '50', '75'], fontsize=30, weight='normal')  # Change to normal case

ax.grid(True, alpha=0.3)
ax.tick_params(axis='x', labelsize=30, pad = 3)  # Kích thước chữ cho trục X
ax.tick_params(axis='y', labelsize=30, pad = 3)  # Kích thước chữ cho trục Y

# Set axis limits to match the example
ax.set_xlim(-90, 90)
ax.set_ylim(-90, 90)
plt.savefig('img/conf_c1_2D', dpi = 600, bbox_inches='tight')

# %% [markdown]
# image for journal

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman']
# plt.rcParams['font.weight'] = 'bold'
rcParams['font.family'] = 'Times New Roman'
# Define font properties for Times New Roman
legend_font = font_manager.FontProperties( style='normal', weight='normal', size=5)
label_font = {'style': 'normal', 'weight': 'normal', 'size': 10}
plt.figure(figsize=(7, 5))
ax = plt.gca()
ax.scatter(x_samples, y_samples, c='b', marker='o',s=10, label='Sample coordinates', alpha =1)
ax.scatter(x_calculated, y_calculated, c= 'r', marker='x',s=15, label='Calculated coordinates', alpha = 1)

ax.set_xlabel('X (cm)', fontdict={'weight': 'normal'}, fontsize=14)
ax.set_ylabel('Y (cm)', fontdict={'weight': 'normal'}, fontsize=14)
ax.legend(loc='upper center', fontsize=12,  bbox_to_anchor=(0.5, 1.13), ncol=2)

ax.set_xticks([-75, -50, -25, 0, 25, 50, 75])
ax.set_yticks([-75, -50, -25, 0, 25, 50, 75])

ax.set_xticklabels(['-75', '-50', '-25', '0', '25', '50', '75'], fontsize=12, weight='normal')  # Change to normal case
ax.set_yticklabels(['-75', '-50', '-25', '0', '25', '50', '75'], fontsize=12, weight='normal')  # Change to normal case

ax.grid(True, alpha=0.3)
ax.tick_params(axis='x', labelsize=12, pad = 3)  # Kích thước chữ cho trục X
ax.tick_params(axis='y', labelsize=12, pad = 3)  # Kích thước chữ cho trục Y

# Set axis limits to match the example
ax.set_xlim(-90, 90)
ax.set_ylim(-90, 90)
plt.savefig('img/c2_2D', dpi = 600, bbox_inches='tight')

# %% [markdown]
# 3D image

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman']
# plt.rcParams['font.weight'] = 'bold'

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_samples, y_samples, z_samples, c='r', marker='o', s= 10, label = 'Sample coordinates', alpha = 1)
ax.scatter(x_calculated, y_calculated, z_calculated, c='b', marker='x', s=10, label = 'Calculated coordinates', alpha = 1)

ax.set_xlabel('X (cm)', fontdict={'weight': 'normal'}, fontsize = 14, labelpad=2)
ax.set_ylabel('Y (cm)', fontdict={'weight': 'normal'}, fontsize = 14, labelpad=2)
ax.set_zlabel('Z (cm)', fontdict={'weight': 'normal'}, fontsize = 14, labelpad=2)

ax.set_xlim(-100, 100)
ax.set_ylim(-100, 100)
ax.set_zlim(100, 140)
ax.grid(True)
ax.legend(loc='upper center', fontsize=12,  bbox_to_anchor=(0.26, .4), ncol=1)

# Adjust view angle
ax.view_init(elev=12, azim=60)

ax.set_xticks([-100, -50, 0, 50, 100])
ax.set_yticks([-100, -50, 0, 50, 100])
ax.set_zticks([ 110, 120, 130, 140])

ax.set_xticklabels(['-100', '-50', '0', '50', '100'], fontsize=12, weight='normal')  # Change to normal case
ax.set_yticklabels(['-100', '-50', '0', '50', '100'], fontsize=12, weight='normal')  # Change to normal case
ax.set_zticklabels(['110', '120', '130', '140'], fontsize=12, weight='normal')  # Change to normal case

ax.tick_params(axis='x', labelsize=12, pad = 2)  # Kích thước chữ cho trục X
ax.tick_params(axis='y', labelsize=12, pad = 2)  # Kích thước chữ cho trục Y
ax.tick_params(axis='z', labelsize=12, pad = 2)  # Kích thước chữ cho trục Z

# Remove top and right spines
# ax.w_xaxis.line.set_color((1.0, 1.0, 1.0, 0.0))
# ax.w_yaxis.line.set_color((1.0, 1.0, 1.0, 0.0))
# ax.w_zaxis.line.set_color((1.0, 1.0, 1.0, 0.0))
plt.show()
fig.savefig('img/c2_3D', dpi = 600, bbox_inches='tight')

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman']

# print(delta_xy)
data_sorted = np.sort(delta_xy)
data_xyz_sorted = np.sort(delta_xyz)


# print(data_sorted)
cdf = np.arange(1, len(data_sorted) + 1) / len(data_sorted)
cdf2 = np.arange(1, len(data_xyz_sorted) + 1) / len(data_xyz_sorted)


# Vẽ biểu đồ CDF
plt.figure(figsize=(2, 2))
ax = plt.gca()


# Vẽ CDF
ax.plot(data_sorted, cdf, linestyle='-', color='blue', linewidth = 1, label = '2D Positionning')

ax.plot(data_xyz_sorted, cdf2, linestyle='-', color='orange', linewidth = 1, label = '3D Positionning')

# Thêm nhãn và tiêu đề
ax.set_xlabel('Error (cm)', fontdict={'weight': 'normal'}, fontsize = 10, labelpad=2)
ax.set_ylabel('CDF', fontdict={'weight': 'normal'}, fontsize = 10, labelpad=2)

ax.legend(loc = (-0.3, 1.05), fontsize = 8, ncol=2 )
# Hiển thị lưới
ax.grid(True, alpha=0.3)


ax.tick_params(axis='x', labelsize=10)  # Kích thước chữ cho trục X
ax.tick_params(axis='y', labelsize=10)  # Kích thước chữ cho trục Y

plt.savefig('img/c2_CDF',dpi = 600,bbox_inches='tight')

# %%
# Dữ liệu giả định (có thể thay thế bằng dữ liệu thực tế của bạn)
# data = [-6, -6, -4, -4, -2, 0, 2, 4, 6, 6, 6, 8, 8]

# Thiết lập bins cho các khoảng giá trị
bins = np.arange(-6, 10, 1)

# Vẽ biểu đồ cột
plt.hist(delta_x, bins=bins, color='cyan', edgecolor='black', label='Phân phối sai số trục X')

# Gắn tiêu đề và nhãn trục
plt.title('Phân phối sai số trục X')
plt.xlabel('Sai số (cm)')
plt.ylabel('Số giá trị')

# Thêm chú thích
plt.legend()

# Hiển thị biểu đồ
plt.show()

# %%
# Dữ liệu giả định (có thể thay thế bằng dữ liệu thực tế của bạn)
# data = [-6, -6, -4, -4, -2, 0, 2, 4, 6, 6, 6, 8, 8]

# Thiết lập bins cho các khoảng giá trị
bins = np.arange(-7, 10, 1)

# Vẽ biểu đồ cột
plt.hist(delta_y, bins=bins, color='cyan', edgecolor='black', label='Phân phối sai số trục Y')

# Gắn tiêu đề và nhãn trục
plt.title('Phân phối sai số trục Y')
plt.xlabel('Sai số (cm)')
plt.ylabel('Số giá trị')

# Thêm chú thích
plt.legend()

# Hiển thị biểu đồ
plt.show()

# %% [markdown]
# Z-AXIS

# %%
# Dữ liệu giả định (có thể thay thế bằng dữ liệu thực tế của bạn)
# data = [-6, -6, -4, -4, -2, 0, 2, 4, 6, 6, 6, 8, 8]
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman']
# Thiết lập bins cho các khoảng giá trị
plt.figure(figsize=(2,2))
bins = np.arange(-4, 10, 1)

# Vẽ biểu đồ cột
plt.hist(delta_z, bins=bins, color='cyan', edgecolor='black', label='Error along Z-axis')

# Gắn tiêu đề và nhãn trục

plt.xlabel('Error (cm)',  fontsize = 10,labelpad=1)
plt.ylabel('The numper of positions',fontsize = 10, labelpad=1)
# Thêm chú thích

plt.xticks([-4, 0, 4, 8], ['-4', '0', '4', '8'], fontsize=10, weight='normal')
plt.yticks([0, 10, 20, 30, 40], ['0', '10', '20', '30', '40'], fontsize=10, weight='normal')
# plt.legend(loc = (0.1, 1.01), fontsize = 8)
plt.savefig('img/c2_Err_Z_axis',dpi = 600,bbox_inches='tight')

# Hiển thị biểu đồ
plt.show()

# %%
# Dữ liệu giả định (có thể thay thế bằng dữ liệu thực tế của bạn)
# data = [-6, -6, -4, -4, -2, 0, 2, 4, 6, 6, 6, 8, 8]

# Thiết lập bins cho các khoảng giá trị
plt.figure(figsize=(2,2))
bins = np.arange(1, 9, 1)

# Vẽ biểu đồ cột
plt.hist(delta_xy, bins=bins, color='orange', edgecolor='black', label='Error on a 2D plane')

# Gắn tiêu đề và nhãn trục
plt.xlabel('Error (cm)', fontsize = 10)
plt.ylabel('The number of positions', fontsize = 10)

# Thêm chú thích
# plt.legend(loc = (0.09, 1.01), fontsize = 8)
plt.xticks([1, 3, 5, 7], ['1', '3', '5', '7'], fontsize=10, weight='normal')
plt.yticks([0, 25, 50], ['0', '25', '50'], fontsize=10, weight='normal')
plt.savefig('img/c2_Err_dis_2D',dpi = 600,bbox_inches='tight')

# Hiển thị biểu đồ
plt.show()

# %%
# Dữ liệu giả định (có thể thay thế bằng dữ liệu thực tế của bạn)
# data = [-6, -6, -4, -4, -2, 0, 2, 4, 6, 6, 6, 8, 8]

# Thiết lập bins cho các khoảng giá trị
bins = np.arange(2, 14, 1)

# Vẽ biểu đồ cột
plt.hist(delta_xyz, bins=bins, color='orange', edgecolor='black', label='Error distribution on a 3D space')

# Gắn tiêu đề và nhãn trục
plt.title('Error distribution on a 3D space', fontsize = 20)
plt.xlabel('Error (cm)', fontsize = 18)
plt.ylabel('The number of positions', fontsize = 18)

# Thêm chú thích
# plt.legend()
plt.xticks(fontsize=16)  # This sets the font size of the bin labels
plt.yticks(fontsize=18)  # Similarly, you can adjust the font size of the y-axis tick labels
# Hiển thị biểu đồ
plt.savefig('img/c1_Err_dis_3D',dpi = 400,bbox_inches='tight')
plt.show()
