# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import font_manager, rcParams
print(rcParams['font.family'])
# Out:
# ['sans-serif']

# %%
path_file2 = "E:\Project\OOC\LEDs_Data_Processing\Encode_Decode\draw\data\mppm-copy.xlsx" ## for the 2 LED
path_file1 = "E:\Project\OOC\LEDs_Data_Processing\Encode_Decode\draw\data\mppm.xlsx"  ## for the 1 LED

df1 = pd.read_excel(path_file1)
df2 = pd.read_excel(path_file2)

# print(df)

# %%
distance = df1.iloc[: 10, 0]
# print(distance)

c1_14khz_accuracy= df1.iloc[:10, 1].to_list()
c1_18khz_accuracy= df1.iloc[10:20, 1].to_list()
c1_20khz_accuracy= df1.iloc[20:30, 1].to_list()

# print(distance)
c2_14khz_accuracy= df2.iloc[:10, 2].to_list()
c2_18khz_accuracy= df2.iloc[10:20, 2].to_list()
c2_20khz_accuracy= df2.iloc[20:30, 2].to_list()


c3_14khz_accuracy= df2.iloc[:10, 3].to_list()
c3_18khz_accuracy= df2.iloc[10:20, 3].to_list()
c3_20khz_accuracy= df2.iloc[20:30, 3].to_list()


_14khz_ber = df1.iloc[:10, 5].to_list()
_18khz_ber = df1.iloc[10:20, 5].to_list()
_20khz_ber = df1.iloc[20:30, 5].to_list()

_2LED_14khz_ber = df2.iloc[:10, 5].to_list()
_2LED_18khz_ber = df2.iloc[10:20, 5].to_list()
_2LED_20khz_ber = df2.iloc[20:30, 5].to_list()
# print(c3_20khz_accuracy)

# %% [markdown]
# 1 led 14khz

# %%
from matplotlib import font_manager


rcParams['font.family'] = 'Times New Roman'
# Define font properties for Times New Roman
legend_font = font_manager.FontProperties( style='normal', weight='normal', size=8)
label_font = {'style': 'normal', 'weight': 'normal', 'size': 8}

fig, ax1 = plt.subplots(figsize=(2, 2))

ax1.set_xlabel('Distance (m)', fontsize=10, fontdict=label_font)
ax1.tick_params(axis='x', labelcolor='black', labelsize=10, pad = 3)
ax1.set_xticks([1.5, 1.7, 1.9, 2.1, 2.3])

ax1.set_ylabel('Decodable frame rate (%)', color='black', fontsize=10, fontdict=label_font)
# ax1.set_xlim(1.6, 2)
ax1.set_ylim(-2, 100)
ax1.tick_params(axis='y', labelcolor='black', labelsize=10, pad = 2)
ax1.set_yticks([0, 20, 40, 60, 80, 100])
line1 = ax1.plot(distance, c1_14khz_accuracy, color='Blue', label='DFR of code 1 (%)', marker='o', markersize=2, linewidth=1)

# # ax1.scatter(distance, c1_code1_accuracy, color='blue', edgecolors='blue', s=3)
# for i, txt in enumerate(c1_14khz_accuracy):
#     if i in [0, 2, 4, 6]:
#         ax1.annotate(f'{txt:.2f}', (distance[i], c1_14khz_accuracy[i]), textcoords="offset points", 
#                      xytext=(6,4), ha='center', color='black', fontsize=6, fontstyle='normal')
        

# txt0 = c1_14khz_accuracy[0]
# ax1.annotate(f'{txt0:.2f}', (distance[0], c1_14khz_accuracy[0]), textcoords="offset points", 
#                 xytext=(10,-10), ha='center', color='black', fontsize=6, fontstyle='normal')

txt1 = c1_14khz_accuracy[2]
ax1.annotate(f'{txt1:.2f}', (distance[2], c1_14khz_accuracy[2]), textcoords="offset points", 
                xytext=(10,-16), ha='center', color='black', fontsize=7, fontstyle='normal')

# txt2 = c1_14khz_accuracy[4]
# ax1.annotate(f'{txt2:.2f}', (distance[4], c1_14khz_accuracy[4]), textcoords="offset points", 
#                 xytext=(10, 0), ha='center', color='black', fontsize=6, fontstyle='normal')   

txt3 = c1_14khz_accuracy[6]
ax1.annotate(f'{txt3:.2f}', (distance[6], c1_14khz_accuracy[6]), textcoords="offset points", 
                xytext=(3,2.9), ha='center', color='black', fontsize=7, fontstyle='normal')   

ax2 = ax1.twinx()
ax2.set_ylim(-0.16, 6)
ax2.set_ylabel('Bit Error Rate (%)', color='black', fontsize=10, fontdict=label_font)
ax2.tick_params(axis='y', labelcolor='black', labelsize=10, pad = 2)
line3 = ax2.plot(distance, _14khz_ber, color='red', label='BER (%)', linestyle='--', marker='o', markersize=2, linewidth=1)


peak_index = np.argmax(_14khz_ber)  # Index of the peak point
peak_value = _14khz_ber[peak_index]  # Value of the peak point
peak_distance = distance[peak_index]  # Distance of the peak point
ax2.annotate(f'Max = {peak_value:.2f}', 
             (peak_distance, peak_value), 
             textcoords="offset points", 
             xytext=(0, 6), 
             ha='center', 
             color='red', 
             fontsize=7, 
             fontstyle='normal', 
             fontweight='bold',
             family='Times New Roman',
             arrowprops=dict(facecolor='red', edgecolor='none', shrink=0.1, width=2, headwidth=3, headlength=4))

lines = ax1.get_lines() + ax2.get_lines()
labels = [line.get_label() for line in lines]

# Move the legend above the plot, outside the graph
ax1.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, 1.2), ncol=2, prop=legend_font)

plt.savefig('E:\Project\OOC\LEDs_Data_Processing\Encode_Decode\draw\img\_1led_14khz.jpeg', dpi = 600,bbox_inches='tight')

# %% [markdown]
# 1 led 18khz

# %%
from matplotlib import font_manager


rcParams['font.family'] = 'Times New Roman'
# Define font properties for Times New Roman
legend_font = font_manager.FontProperties( style='normal', weight='normal', size=8)
label_font = {'style': 'normal', 'weight': 'normal', 'size': 8}

fig, ax1 = plt.subplots(figsize=(2, 2))

ax1.set_xlabel('Distance (m)', fontsize=10, fontdict=label_font)
ax1.tick_params(axis='x', labelcolor='black', labelsize=10, pad = 3)
ax1.set_xticks([1.5, 1.7, 1.9, 2.1, 2.3])

ax1.set_ylabel('Decodable frame rate (%)', color='black', fontsize=10, fontdict=label_font)
# ax1.set_xlim(1.6, 2)
ax1.set_ylim(-2, 100)
ax1.tick_params(axis='y', labelcolor='black', labelsize=10, pad = 2)
ax1.set_yticks([0, 20, 40, 60, 80, 100])
line1 = ax1.plot(distance, c1_20khz_accuracy, color='Blue', label='DFR of code 1 (%)', marker='o', markersize=2, linewidth=1)

# ax1.scatter(distance, c1_code1_accuracy, color='blue', edgecolors='blue', s=3)

# txt0 = c1_18khz_accuracy[0]
# ax1.annotate(f'{txt0:.2f}', (distance[0], c1_18khz_accuracy[0]), textcoords="offset points", 
#                 xytext=(10,-10), ha='center', color='black', fontsize=6, fontstyle='normal')

txt1 = c1_18khz_accuracy[2]
ax1.annotate(f'{txt1:.2f}', (distance[2], c1_18khz_accuracy[2]), textcoords="offset points", 
                xytext=(10,-12), ha='center', color='black', fontsize=7, fontstyle='normal')

# txt2 = c1_18khz_accuracy[4]
# ax1.annotate(f'{txt2:.2f}', (distance[4], c1_18khz_accuracy[4]), textcoords="offset points", 
#                 xytext=(10, 0), ha='center', color='black', fontsize=6, fontstyle='normal')   

txt3 = c1_18khz_accuracy[6]
ax1.annotate(f'{txt3:.2f}', (distance[6], c1_18khz_accuracy[6]), textcoords="offset points", 
                xytext=(10,-18), ha='center', color='black', fontsize=7, fontstyle='normal')   

# for i, txt in enumerate(c1_18khz_accuracy):
#     if i in [0, 2, 4, 6]:
#         ax1.annotate(f'{txt:.2f}', (distance[i], c1_18khz_accuracy[i]), textcoords="offset points", 
#                      xytext=(10,-15), ha='center', color='black', fontsize=8, fontstyle='normal')        

ax2 = ax1.twinx()
ax2.set_ylim(-0.16, 6)
ax2.set_ylabel('Bit Error Rate (%)', color='black', fontsize=10, fontdict=label_font)
ax2.tick_params(axis='y', labelcolor='black', labelsize=10, pad = 2)
line3 = ax2.plot(distance, _18khz_ber, color='red', label='BER (%)', linestyle='--', marker='o', markersize=2, linewidth=1)


peak_index = np.argmax(_18khz_ber)  # Index of the peak point
peak_value = _18khz_ber[peak_index]  # Value of the peak point
peak_distance = distance[peak_index]  # Distance of the peak point
ax2.annotate(f'Max = {peak_value:.2f}', 
             (peak_distance, peak_value), 
             textcoords="offset points", 
             xytext=(0, 6), 
             ha='center', 
             color='red', 
             fontsize=7, 
             fontstyle='normal', 
             fontweight='bold',
             family='Times New Roman',
             arrowprops=dict(facecolor='red', edgecolor='none', shrink=0.1, width=2, headwidth=3, headlength=4))

lines = ax1.get_lines() + ax2.get_lines()
labels = [line.get_label() for line in lines]

# Move the legend above the plot, outside the graph
ax1.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, 1.2), ncol=2, prop=legend_font)

plt.savefig('E:\Project\OOC\LEDs_Data_Processing\Encode_Decode\draw\img\_1led_18khz.jpeg', dpi = 600,bbox_inches='tight')

# %% [markdown]
# 1 LED 20kHz

# %%
from matplotlib import font_manager


rcParams['font.family'] = 'Times New Roman'
# Define font properties for Times New Roman
legend_font = font_manager.FontProperties( style='normal', weight='normal', size=8)
label_font = {'style': 'normal', 'weight': 'normal', 'size': 8}

fig, ax1 = plt.subplots(figsize=(2, 2))

ax1.set_xlabel('Distance (m)', fontsize=10, fontdict=label_font)
ax1.tick_params(axis='x', labelcolor='black', labelsize=10, pad = 1)
ax1.set_xticks([1.5, 1.7, 1.9, 2.1, 2.3])

ax1.set_ylabel('Decodable frame rate (%)', color='black', fontsize=10, fontdict=label_font)
# ax1.set_xlim(1.6, 2)
ax1.set_ylim(-2, 100)
ax1.tick_params(axis='y', labelcolor='black', labelsize=10, pad = 1)
ax1.set_yticks([0, 20, 40, 60, 80, 100])
line1 = ax1.plot(distance, c1_20khz_accuracy, color='Blue', label='DFR of code 1 (%)', marker='o', markersize=2, linewidth=1)

# ax1.scatter(distance, c1_code1_accuracy, color='blue', edgecolors='blue', s=3)

# txt0 = c1_20khz_accuracy[0]
# ax1.annotate(f'{txt0:.2f}', (distance[0], c1_20khz_accuracy[0]), textcoords="offset points", 
#                 xytext=(10,-10), ha='center', color='black', fontsize=6, fontstyle='normal')

txt1 = c1_20khz_accuracy[2]
ax1.annotate(f'{txt1:.2f}', (distance[2], c1_20khz_accuracy[2]), textcoords="offset points", 
                xytext=(10,-11), ha='center', color='black', fontsize=7, fontstyle='normal')

# txt2 = c1_20khz_accuracy[4]
# ax1.annotate(f'{txt2:.2f}', (distance[4], c1_20khz_accuracy[4]), textcoords="offset points", 
#                 xytext=(10, 3), ha='center', color='black', fontsize=6, fontstyle='normal')   

txt3 = c1_20khz_accuracy[6]
ax1.annotate(f'{txt3:.2f}', (distance[6], c1_20khz_accuracy[6]), textcoords="offset points", 
                xytext=(12,-3), ha='center', color='black', fontsize=7, fontstyle='normal')   

# for i, txt in enumerate(c1_20khz_accuracy):
#     if i in [0, 2, 4, 6]:
#         ax1.annotate(f'{txt:.2f}', (distance[i], c1_20khz_accuracy[i]), textcoords="offset points", 
#                      xytext=(10,-15), ha='center', color='black', fontsize=8, fontstyle='normal')        

ax2 = ax1.twinx()
ax2.set_ylim(-0.16, 6)
ax2.set_ylabel('Bit Error Rate (%)', color='black', fontsize=10, fontdict=label_font)
ax2.tick_params(axis='y', labelcolor='black', labelsize=10, pad = 2)
line3 = ax2.plot(distance, _20khz_ber, color='red', label='BER (%)', linestyle='--', marker='o', markersize=2, linewidth=1)

peak_index = np.argmax(_20khz_ber)  # Index of the peak point
peak_value = _20khz_ber[peak_index]  # Value of the peak point
peak_distance = distance[peak_index]  # Distance of the peak point
ax2.annotate(f'Max = {peak_value:.2f}', 
             (peak_distance, peak_value), 
             textcoords="offset points", 
             xytext=(0, 6), 
             ha='center', 
             color='red', 
             fontsize=7, 
             fontstyle='normal', 
             fontweight='bold',
             family='Times New Roman',
             arrowprops=dict(facecolor='red', edgecolor='none', shrink=0.1, width=2, headwidth=3, headlength=4))

lines = ax1.get_lines() + ax2.get_lines()
labels = [line.get_label() for line in lines]

# Move the legend above the plot, outside the graph
ax1.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, 1.2), ncol=2, prop=legend_font)

plt.savefig('E:\Project\OOC\LEDs_Data_Processing\Encode_Decode\draw\img\_1led_20khz.jpeg', dpi = 600,bbox_inches='tight')

# %%
rcParams['font.family'] = 'Times New Roman'
# Define font properties for Times New Roman
legend_font = font_manager.FontProperties( style='normal', weight='normal', size=8)
label_font = {'style': 'normal', 'weight': 'normal', 'size': 8}

fig, ax1 = plt.subplots(figsize=(2, 2))


ax1.set_xlabel('Distance (m)', fontsize=10, fontdict=label_font)
ax1.tick_params(axis='x', labelcolor='black', labelsize=10, pad = 1)
ax1.set_xticks([1.5, 1.7, 1.9, 2.1, 2.3])


ax1.set_ylabel('Decodable frame rate (%)', color='black', fontsize=10, fontdict=label_font)
# ax1.set_xlim(1.6, 2)
ax1.set_ylim(-2, 100)
ax1.tick_params(axis='y', labelcolor='black', labelsize=10, pad = 1)
ax1.set_yticks([0, 20, 40, 60, 80, 100])

line1 =ax1.plot(distance, c2_14khz_accuracy, color='Blue', label='DFR of code 2 (%)', marker = 'o',  markersize=2, linewidth=1)
line2 =ax1.plot(distance, c3_14khz_accuracy, color='Green', label='DFR of code 3 (%)', marker = 's',  markersize=2, linewidth=1)


# txt0 = c2_14khz_accuracy[0]
# ax1.annotate(f'{txt0:.2f}', (distance[0], c2_14khz_accuracy[0]), textcoords="offset points", 
#                 xytext=(15,-3), ha='center', color='black', fontsize=6, fontstyle='normal')

txt1 = c2_14khz_accuracy[2]
ax1.annotate(f'{txt1:.2f}', (distance[2], c2_14khz_accuracy[2]), textcoords="offset points", 
                xytext=(9, -22), ha='center', color='black', fontsize=7, fontstyle='normal')

# txt2 = c2_14khz_accuracy[4]
# ax1.annotate(f'{txt2:.2f}', (distance[4], c2_14khz_accuracy[4]), textcoords="offset points", 
#                 xytext=(9, -19), ha='center', color='black', fontsize=6, fontstyle='normal')   

txt3 = c2_14khz_accuracy[6]
ax1.annotate(f'{txt3:.2f}', (distance[6], c2_14khz_accuracy[6]), textcoords="offset points", 
                xytext=(4, 4), ha='center', color='black', fontsize=7, fontstyle='normal')   


ax2 = ax1.twinx()
ax2.set_ylim(-0.16, 6)
ax2.set_ylabel('Bit Error Rate (%)', color='black', fontsize=10, fontdict=label_font)
line3 = ax2.plot(distance, _2LED_14khz_ber, color='red', label='BER (%)', linestyle='--', marker = 'o',  markersize=2, linewidth=1)
ax2.tick_params(axis='y', labelcolor='black')

peak_index = np.argmax(_2LED_14khz_ber)  # Chỉ số của điểm cực đại
peak_value = _2LED_14khz_ber[peak_index]  # Giá trị của điểm cực đại
peak_distance = distance[peak_index]  # Khoảng cách của điểm cực đại
ax2.annotate(f'Max = {peak_value:.2f}', 
             (peak_distance, peak_value), 
             textcoords="offset points", 
             xytext=(0, 6), 
             ha='center', 
             color='red', 
             fontsize=7, 
             fontstyle='normal', 
             fontweight='bold',
             family='Times New Roman',
             arrowprops=dict(facecolor='red', edgecolor='none', shrink=0.1, width=2, headwidth=3, headlength=4))


lines = ax1.get_lines() + ax2.get_lines()
labels = [line.get_label() for line in lines]

# Move the legend above the plot, outside the graph
ax1.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, 1.3), ncol=2, prop=legend_font)

plt.savefig('E:\Project\OOC\LEDs_Data_Processing\Encode_Decode\draw\img\_2led_14khz.jpeg',dpi = 600,bbox_inches='tight')

# %% [markdown]
# 2 LED 18 kHz

# %%
rcParams['font.family'] = 'Times New Roman'
# Define font properties for Times New Roman
legend_font = font_manager.FontProperties( style='normal', weight='normal', size=8)
label_font = {'style': 'normal', 'weight': 'normal', 'size': 8}

fig, ax1 = plt.subplots(figsize=(2, 2))


ax1.set_xlabel('Distance (m)', fontsize=10, fontdict=label_font)
ax1.tick_params(axis='x', labelcolor='black', labelsize=10, pad = 1)
ax1.set_xticks([1.5, 1.7, 1.9, 2.1, 2.3])


ax1.set_ylabel('Decodable frame rate (%)', color='black', fontsize=10, fontdict=label_font)
# ax1.set_xlim(1.6, 2)
ax1.set_ylim(-2, 100)
ax1.tick_params(axis='y', labelcolor='black', labelsize=10, pad = 1)
ax1.set_yticks([0, 20, 40, 60, 80, 100])

line1 =ax1.plot(distance, c2_18khz_accuracy, color='Blue', label='DFR of code 2 (%)', marker = 'o',  markersize=2, linewidth=1)
line2 =ax1.plot(distance, c3_18khz_accuracy, color='Green', label='DFR of code 3 (%)', marker = 's',  markersize=2, linewidth=1)

# ax1.scatter(distance, c1_code1_accuracy, color='blue', edgecolors='blue', s=3)
# for i, txt in enumerate(c2_18khz_accuracy):
#     if i in [0, 4]:
#         ax1.annotate(f'{txt:.2f}', (distance[i], c2_18khz_accuracy[i]), textcoords="offset points", xytext=(0,-15), ha='center', color='black', fontsize=10)
# for i, txt in enumerate(c3_18khz_accuracy):
#     if i in [4]:
#         ax1.annotate(f'{txt:.2f}', (distance[i], c2_18khz_accuracy[i]), textcoords="offset points", xytext=(10,6), ha='center', color='black', fontsize=10)


# txt0 = c2_18khz_accuracy[0]
# ax1.annotate(f'{txt0:.2f}', (distance[0], c2_18khz_accuracy[0]), textcoords="offset points", 
#                 xytext=(10,-8), ha='center', color='black', fontsize=6, fontstyle='normal')

txt1 = c2_18khz_accuracy[2]
ax1.annotate(f'{txt1:.2f}', (distance[2], c2_18khz_accuracy[2]), textcoords="offset points", 
                xytext=(10,-11), ha='center', color='black', fontsize=7, fontstyle='normal')

# txt2 = c2_18khz_accuracy[4]
# ax1.annotate(f'{txt2:.2f}', (distance[4], c2_18khz_accuracy[4]), textcoords="offset points", 
#                 xytext=(9, -9), ha='center', color='black', fontsize=6, fontstyle='normal')   

txt3 = c2_18khz_accuracy[6]
ax1.annotate(f'{txt3:.2f}', (distance[6], c2_18khz_accuracy[6]), textcoords="offset points", 
                xytext=(13, 1), ha='center', color='black', fontsize=7, fontstyle='normal')   


ax2 = ax1.twinx()
ax2.set_ylim(-0.16, 6)
ax2.set_ylabel('Bit Error Rate (%)', color='black', fontsize=10, fontdict=label_font)
line3 = ax2.plot(distance, _2LED_18khz_ber, color='red', label='BER (%)', linestyle='--', marker = 'o',  markersize=2, linewidth=1)
ax2.tick_params(axis='y', labelcolor='black')

peak_index = np.argmax(_2LED_18khz_ber)  # Chỉ số của điểm cực đại
peak_value = _2LED_18khz_ber[peak_index]  # Giá trị của điểm cực đại
peak_distance = distance[peak_index]  # Khoảng cách của điểm cực đại
ax2.annotate(f'Max = {peak_value:.2f}', 
             (peak_distance, peak_value), 
             textcoords="offset points", 
             xytext=(0, 6), 
             ha='center', 
             color='red', 
             fontsize=7, 
             fontstyle='normal', 
             fontweight='bold',
             family='Times New Roman',
             arrowprops=dict(facecolor='red', edgecolor='none', shrink=0.1, width=2, headwidth=3, headlength=4))


lines = ax1.get_lines() + ax2.get_lines()
labels = [line.get_label() for line in lines]

# Move the legend above the plot, outside the graph
ax1.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, 1.3), ncol=2, prop=legend_font)

plt.savefig('E:\Project\OOC\LEDs_Data_Processing\Encode_Decode\draw\img\_2led_18khz.jpeg',dpi = 600,bbox_inches='tight')

# %% [markdown]
# 2 LED 20kHz

# %%
rcParams['font.family'] = 'Times New Roman'
# Define font properties for Times New Roman
legend_font = font_manager.FontProperties( style='normal', weight='normal', size=8)
label_font = {'style': 'normal', 'weight': 'normal', 'size': 8}
fig, ax1 = plt.subplots(figsize=(2, 2))


ax1.set_xlabel('Distance (m)', fontsize=10, fontdict=label_font)
ax1.tick_params(axis='x', labelcolor='black', labelsize=10, pad = 1)
ax1.set_xticks([1.5, 1.7, 1.9, 2.1, 2.3])


ax1.set_ylabel('Decodable frame rate (%)', color='black', fontsize=10, fontdict=label_font)
# ax1.set_xlim(1.6, 2)
ax1.set_ylim(-2, 100)
ax1.tick_params(axis='y', labelcolor='black', labelsize=10, pad = 1)
ax1.set_yticks([0, 20, 40, 60, 80, 100])

line1 =ax1.plot(distance, c2_20khz_accuracy, color='Blue', label='DFR of code 2 (%)', marker = 'o',  markersize=2, linewidth=1)
line2 =ax1.plot(distance, c3_20khz_accuracy, color='Green', label='DFR of code 3 (%)', marker = 's',  markersize=2, linewidth=1)

# ax1.scatter(distance, c1_code1_accuracy, color='blue', edgecolors='blue', s=3)
# for i, txt in enumerate(c2_20khz_accuracy):
#     if i in [0, 4]:
#         ax1.annotate(f'{txt:.2f}', (distance[i], c2_20khz_accuracy[i]), textcoords="offset points", xytext=(0,-15), ha='center', color='black', fontsize=10)
# for i, txt in enumerate(c3_20khz_accuracy):
#     if i in [4]:
#         ax1.annotate(f'{txt:.2f}', (distance[i], c2_20khz_accuracy[i]), textcoords="offset points", xytext=(10,6), ha='center', color='black', fontsize=10)


# txt0 = c2_20khz_accuracy[0]
# ax1.annotate(f'{txt0:.2f}', (distance[0], c2_20khz_accuracy[0]), textcoords="offset points", 
#                 xytext=(10,-8), ha='center', color='black', fontsize=6, fontstyle='normal')

txt1 = c2_20khz_accuracy[2]
ax1.annotate(f'{txt1:.2f}', (distance[2], c2_20khz_accuracy[2]), textcoords="offset points", 
                xytext=(10,-9), ha='center', color='black', fontsize=7, fontstyle='normal')

# txt2 = c2_20khz_accuracy[4]
# ax1.annotate(f'{txt2:.2f}', (distance[4], c2_20khz_accuracy[4]), textcoords="offset points", 
#                 xytext=(9, -9), ha='center', color='black', fontsize=6, fontstyle='normal')   

txt3 = c2_20khz_accuracy[6]
ax1.annotate(f'{txt3:.2f}', (distance[6], c2_20khz_accuracy[6]), textcoords="offset points", 
                xytext=(13, -1), ha='center', color='black', fontsize=7, fontstyle='normal')   


ax2 = ax1.twinx()
ax2.set_ylim(-0.16, 6)
ax2.set_ylabel('Bit Error Rate (%)', color='black', fontsize=10, fontdict=label_font)
line3 = ax2.plot(distance, _2LED_20khz_ber, color='red', label='BER (%)', linestyle='--', marker = 'o',  markersize=2, linewidth=1)
ax2.tick_params(axis='y', labelcolor='black')

peak_index = np.argmax(_2LED_20khz_ber)  # Chỉ số của điểm cực đại
peak_value = _2LED_20khz_ber[peak_index]  # Giá trị của điểm cực đại
peak_distance = distance[peak_index]  # Khoảng cách của điểm cực đại
ax2.annotate(f'Max = {peak_value:.2f}', 
             (peak_distance, peak_value), 
             textcoords="offset points", 
             xytext=(-4, 5), 
             ha='center', 
             color='red', 
             fontsize=7, 
             fontstyle='normal', 
             fontweight='bold',
             family='Times New Roman',
             arrowprops=dict(facecolor='red', edgecolor='none', shrink=0.1, width=2, headwidth=3, headlength=4))


lines = ax1.get_lines() + ax2.get_lines()
labels = [line.get_label() for line in lines]

# Move the legend above the plot, outside the graph
ax1.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, 1.3), ncol=2, prop=legend_font)

plt.savefig('E:\Project\OOC\LEDs_Data_Processing\Encode_Decode\draw\img\_2led_20khz.png',dpi = 600,bbox_inches='tight')
